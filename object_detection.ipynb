# %% [markdown]
# <a href="https://colab.research.google.com/github/TheMuffin0000/Real-Time-Object-Detection/blob/main/object_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('welcom to my project')
# Out:
# welcom to my project

# %%
# ===== Core Deep Learning =====
#from ultralytics import YOLO
import torch

# ===== Image & Video Processing =====
import cv2
import numpy as np
from PIL import Image

# ===== Web App (Streamlit) =====
#import streamlit as st
import tempfile

# ===== Visualization (optional but useful) =====
import matplotlib.pyplot as plt

# ===== Utilities =====
import time
import logging
